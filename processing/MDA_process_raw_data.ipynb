# %%
import numpy as np
import pandas as pd
import scanpy as sc

# %%
sc.settings.verbosity = 2             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)
# Out:
# scanpy==1.4.5.post2 anndata==0.7.1 umap==0.3.10 numpy==1.17.2 scipy==1.3.1 pandas==0.25.1 scikit-learn==0.21.3 statsmodels==0.10.1 python-igraph==0.7.1

# %%
from process_raw_data import *

# %% [markdown]
# ### Set up processing parameters

# %%
cellBCpath = '/wynton/scratch/bp205/barcodes/MDA_barcode_identities.csv'
geneBCpath = '/wynton/scratch/bp205/barcodes/sample_barcodes/MDA_genetic_barcodes.txt'
matrixPath = '/wynton/scratch/bp205/raw/MDA_BW/filtered_feature_bc_matrix'
outfilePath = '/wynton/scratch/bp205/processed/MDA_filtered_normalized_adata.h5ad'

minN_genes = 200
minN_cells = 3
maxN_genes = 7000
maxMito_percent = 0.1

# %% [markdown]
# ### Load Cell barcodes and Sample barcodes

# %%
cellBC = pd.read_csv(cellBCpath, usecols=[1,2,3])
cellBC = cellBC[cellBC['multiseq barcode']!='DOUBLET']

geneBC = pd.read_csv(geneBCpath, sep='\t', index_col=0)
BCmap = create_barcode_map(cellBC, geneBC)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-cb2fbb5657bb> in <module>
# ----> 1 cellBC = pd.read_csv(cellBCpath, usecols=[1,2,3])
#       2 cellBC = cellBC[cellBC['multiseq barcode']!='DOUBLET']
#       3
#       4 geneBC = pd.read_csv(geneBCpath, sep='\t', index_col=0)
#       5 BCmap = create_barcode_map(cellBC, geneBC)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/wynton/scratch/bp205/barcodes/MDA_barcode_identities.csv' does not exist: b'/wynton/scratch/bp205/barcodes/MDA_barcode_identities.csv'

# %%
BCmap.head()

# %% [markdown]
# ### Loading raw sample x gene counts matrix

# %%
adata = read_matrix(matrixPath)

# %%
adata = add_cell_type_to_obs(adata, BCmap)

# %%
adata = sc.read_h5ad('/wynton/scratch/bp205/processed/MDA_adata.h5ad')

# %% [markdown]
# ### Visalizing the highest expression genes

# %%
sc.pl.highest_expr_genes(adata, n_top=20, )
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %% [markdown]
# Remove cells with fewer gene counts than a detection threshold, and are found in fewer than $n$ cells

# %%
adata = filter_minGenes_minCells(adata, minN_genes, minN_cells)
# Out:
# filtered out 2017 genes that are detected in less than 3 cells

# %% [markdown]
# Remove all cells which are not mapped to a specific sample (due to degenerate MULTI or genetic barcodes)

# %%
adata = keep_real_cells(adata)

# %% [markdown]
# ### Determining % mitochondria-associated genes

# %%
adata = calc_percentMito_nCounts(adata)
sc.pl.violin(adata, ['n_genes', 'n_counts', 'percent_mito'],
             jitter=0.4, multi_panel=True)
# Out:
# Trying to set attribute `.obs` of view, copying.
# ... storing 'SampleType' as categorical

# %%
sc.pl.scatter(adata, x='n_counts', y='percent_mito')
sc.pl.scatter(adata, x='n_counts', y='n_genes')

# %% [markdown]
# ### Filtering out cells with high gene counts, and high mitochondrial percentage

# %%
adata = filter_genes_mito(adata, maxN_genes, maxMito_percent)

# %% [markdown]
# ### Normalize count matrix (Total Normalization) and log-transform the count values

# %%
adata, backup = normalize_and_log(adata)
# Out:
# normalizing counts per cell
#     finished (0:00:21)
# /wynton/home/pollard/egilbertson/anaconda3/lib/python3.7/site-packages/scanpy/preprocessing/_simple.py:298: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(data)

# %%
adata.write('/wynton/scratch/bp205/processed/MDA_lognorm_adata.h5ad')

# %% [markdown]
# ### Plot highly variable genes

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.02, max_mean=4, min_disp=0.2)
sc.pl.highly_variable_genes(adata)
# Out:
# extracting highly variable genes
#     finished (0:00:02)

# %% [markdown]
# ### Keep only genes which are 'highly variable'

# %%
adata = adata[:, adata.var.highly_variable]

# %% [markdown]
# ### Regress out the mitochondrial fraction and total counts, rescale the data, and perform PCA

# %%
adata = regress_scale_pca(adata)
# Out:
# regressing out ['n_counts', 'percent_mito']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:24)
# computing PCA with n_comps = 50
#     on highly variable genes
#     finished (0:00:02)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 5426 × 3254
#     obs: 'SampleType', 'quality', 'n_genes', 'percent_mito', 'n_counts'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %%
adata.write(outfilePath)
